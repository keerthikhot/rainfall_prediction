# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('C:\\Users\\KEERTI\\Desktop\\machine learning\\projects\\rainfall_prediction\\weatherAUS.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
numerical_feature=[feature for feature in df.columns if df[feature].dtype!='O']
discrete_feature=[feature for feature in numerical_feature if len(df[feature].unique())<25]
continuous_feature=[feature for feature in numerical_feature if feature not in discrete_feature]
categorical_feature=[feature for feature in df.columns if df[feature].dtype=='O']
print("numerical_features are {}".format(len(numerical_feature)))
print("discrete features are {}".format(len(discrete_feature)))
print("continuous features are {}".format(len(continuous_feature)))
print("categorical features are {}".format(len(categorical_feature)))
# Out:
# numerical_features are 16
# discrete features are 2
# continuous features are 14
# categorical features are 7

# %%
discrete_feature
# Out:
# ['Cloud9am', 'Cloud3pm']

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.isnull().sum()*100/len(df)
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020899
# MaxTemp           0.866905
# Rainfall          2.241853
# Evaporation      43.166506
# Sunshine         48.009762
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Cloud9am         38.421559
# Cloud3pm         40.807095
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
df['Evaporation'].dtypes
# Out:
# dtype('float64')

# %%
df['Sunshine'].dtypes
# Out:
# dtype('float64')

# %%
continuous_feature
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustSpeed',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Temp9am',
#  'Temp3pm']

# %%
discrete_feature
# Out:
# ['Cloud9am', 'Cloud3pm']

# %% [markdown]
# # handling of discrete features

# %%
def fill_random(df,variable):
    df[variable]=df[variable]
    random_sample=df[variable].dropna().sample(df[variable].isnull().sum(),random_state=0)
    random_sample.index=df[df[variable].isnull()].index
    df.loc[df[variable].isnull(),variable]=random_sample

# %%
fill_random(df,"Cloud9am")
fill_random(df,'Cloud3pm')
fill_random(df,'Evaporation')
fill_random(df,'Sunshine')

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          2.4       8.3
# 1  2008-12-02   Albury      7.4     25.1       0.0          3.6      10.0
# 2  2008-12-03   Albury     12.9     25.7       0.0          2.6       4.4
# 3  2008-12-04   Albury      9.2     28.0       0.0         18.4       8.9
# 4  2008-12-05   Albury     17.5     32.3       1.0          5.4       3.0
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation          0
# Sunshine             0
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am             0
# Cloud3pm             0
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %% [markdown]
# # handling of continuous features

# %%
for feature in continuous_feature:
    data=df.copy()
    plt.figure(figsize=(5,5))
    sns.displot(df[feature])
    plt.xlabel(feature)
    plt.ylabel('count')
    plt.title(feature)
    plt.show()

# %%
for feature in continuous_feature:
    data=df.copy()
    plt.figure(figsize=(5,5))
    sns.boxplot(data[feature])
    plt.show
# Out:
# C:\Users\KEERTI\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\KEERTI\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for feature in continuous_feature:
    if df[feature].isnull().sum()>0:
        df[feature]=df[feature].fillna(df[feature].median())

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# Evaporation          0
# Sunshine             0
# WindGustDir      10326
# WindGustSpeed        0
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am          0
# Humidity3pm          0
# Pressure9am          0
# Pressure3pm          0
# Cloud9am             0
# Cloud3pm             0
# Temp9am              0
# Temp3pm              0
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %% [markdown]
# # handling categorical features

# %%
categorical_feature
# Out:
# ['Date',
#  'Location',
#  'WindGustDir',
#  'WindDir9am',
#  'WindDir3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
len(df['Location'].unique())
# Out:
# 49

# %%
df['Location'].value_counts()
# Out:
# Canberra            3436
# Sydney              3344
# Darwin              3193
# Melbourne           3193
# Brisbane            3193
# Adelaide            3193
# Perth               3193
# Hobart              3193
# Albany              3040
# MountGambier        3040
# Ballarat            3040
# Townsville          3040
# GoldCoast           3040
# Cairns              3040
# Launceston          3040
# AliceSprings        3040
# Bendigo             3040
# Albury              3040
# MountGinini         3040
# Wollongong          3040
# Newcastle           3039
# Tuggeranong         3039
# Penrith             3039
# Woomera             3009
# Nuriootpa           3009
# Cobar               3009
# CoffsHarbour        3009
# Moree               3009
# Sale                3009
# PerthAirport        3009
# PearceRAAF          3009
# Witchcliffe         3009
# BadgerysCreek       3009
# Mildura             3009
# NorfolkIsland       3009
# MelbourneAirport    3009
# Richmond            3009
# ...

# %%
df['WindGustDir'].value_counts()
# Out:
# W      9915
# SE     9418
# N      9313
# SSE    9216
# E      9181
# S      9168
# WSW    9069
# SW     8967
# SSW    8736
# WNW    8252
# NW     8122
# ENE    8104
# ESE    7372
# NE     7133
# NNW    6620
# NNE    6548
# Name: WindGustDir, dtype: int64

# %%
df['WindDir9am'].value_counts()
# Out:
# N      11758
# SE      9287
# E       9176
# SSE     9112
# NW      8749
# S       8659
# W       8459
# SW      8423
# NNE     8129
# NNW     7980
# ENE     7836
# NE      7671
# ESE     7630
# SSW     7587
# WNW     7414
# WSW     7024
# Name: WindDir9am, dtype: int64

# %%
df['WindDir3pm'].value_counts()
# Out:
# SE     10838
# W      10110
# S       9926
# WSW     9518
# SSE     9399
# SW      9354
# N       8890
# WNW     8874
# NW      8610
# ESE     8505
# E       8472
# NE      8263
# SSW     8156
# NNW     7870
# ENE     7857
# NNE     6590
# Name: WindDir3pm, dtype: int64

# %%
df['RainToday'].value_counts()
# Out:
# No     110319
# Yes     31880
# Name: RainToday, dtype: int64

# %%
df['RainTomorrow'].value_counts()
# Out:
# No     110316
# Yes     31877
# Name: RainTomorrow, dtype: int64

# %%
df['RainToday']=pd.get_dummies(df['RainToday'],drop_first=True)
df['RainTomorrow']=pd.get_dummies(df['RainTomorrow'],drop_first=True)

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          2.4       8.3
# 1  2008-12-02   Albury      7.4     25.1       0.0          3.6      10.0
# 2  2008-12-03   Albury     12.9     25.7       0.0          2.6       4.4
# 3  2008-12-04   Albury      9.2     28.0       0.0         18.4       8.9
# 4  2008-12-05   Albury     17.5     32.3       1.0          5.4       3.0
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df['RainTomorrow'].value_counts()
# Out:
# 0    113583
# 1     31877
# Name: RainTomorrow, dtype: int64

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# Evaporation          0
# Sunshine             0
# WindGustDir      10326
# WindGustSpeed        0
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am          0
# Humidity3pm          0
# Pressure9am          0
# Pressure3pm          0
# Cloud9am             0
# Cloud3pm             0
# Temp9am              0
# Temp3pm              0
# RainToday            0
# RainTomorrow         0
# dtype: int64

# %%
categorical_feature
# Out:
# ['Date',
#  'Location',
#  'WindGustDir',
#  'WindDir9am',
#  'WindDir3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
df[['Date','Location','WindGustDir','WindDir9am','WindDir3pm','RainToday','RainTomorrow']]
# Out:
#               Date Location WindGustDir WindDir9am WindDir3pm  RainToday  \
# 0       2008-12-01   Albury           W          W        WNW          0
# 1       2008-12-02   Albury         WNW        NNW        WSW          0
# 2       2008-12-03   Albury         WSW          W        WSW          0
# 3       2008-12-04   Albury          NE         SE          E          0
# 4       2008-12-05   Albury           W        ENE         NW          0
# ...            ...      ...         ...        ...        ...        ...
# 145455  2017-06-21    Uluru           E         SE        ENE          0
# 145456  2017-06-22    Uluru         NNW         SE          N          0
# 145457  2017-06-23    Uluru           N         SE        WNW          0
# 145458  2017-06-24    Uluru          SE        SSE          N          0
# 145459  2017-06-25    Uluru         NaN        ESE        ESE          0
#
#         RainTomorrow
# 0                  0
# 1                  0
# 2                  0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

df['Location']=labelencoder.fit_transform(df['Location'])
df['WindGustDir']=labelencoder.fit_transform(df['WindGustDir'])
df['WindDir9am']=labelencoder.fit_transform(df['WindDir9am'])
df['WindDir3pm']=labelencoder.fit_transform(df['WindDir3pm'])

# %%
df[['Date','Location','WindGustDir','WindDir9am','WindDir3pm','RainToday','RainTomorrow']]
# Out:
#               Date  Location  WindGustDir  WindDir9am  WindDir3pm  RainToday  \
# 0       2008-12-01         2           13          13          14          0
# 1       2008-12-02         2           14           6          15          0
# 2       2008-12-03         2           15          13          15          0
# 3       2008-12-04         2            4           9           0          0
# 4       2008-12-05         2           13           1           7          0
# ...            ...       ...          ...         ...         ...        ...
# 145455  2017-06-21        41            0           9           1          0
# 145456  2017-06-22        41            6           9           3          0
# 145457  2017-06-23        41            3           9          14          0
# 145458  2017-06-24        41            9          10           3          0
# 145459  2017-06-25        41           16           2           2          0
#
#         RainTomorrow
# 0                  0
# ...

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
df.head()
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01         2     13.4     22.9       0.6          2.4       8.3
# 1  2008-12-02         2      7.4     25.1       0.0          3.6      10.0
# 2  2008-12-03         2     12.9     25.7       0.0          2.6       4.4
# 3  2008-12-04         2      9.2     28.0       0.0         18.4       8.9
# 4  2008-12-05         2     17.5     32.3       1.0          5.4       3.0
#
#    WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# 0           13           44.0          13  ...         71.0         22.0
# 1           14           44.0           6  ...         44.0         25.0
# 2           15           46.0          13  ...         38.0         30.0
# 3            4           24.0           9  ...         45.0         16.0
# 4           13           41.0           1  ...         82.0         33.0
#
# ...

# %%
df.tail()
# Out:
#               Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 145455  2017-06-21        41      2.8     23.4       0.0          1.4
# 145456  2017-06-22        41      3.6     25.3       0.0          7.6
# 145457  2017-06-23        41      5.4     26.9       0.0          6.8
# 145458  2017-06-24        41      7.8     27.0       0.0          2.6
# 145459  2017-06-25        41     14.9     22.6       0.0          1.4
#
#         Sunshine  WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  \
# 145455       7.8            0           31.0           9  ...         51.0
# 145456      13.5            6           22.0           9  ...         56.0
# 145457      11.0            3           37.0           9  ...         53.0
# 145458      13.2            9           28.0          10  ...         51.0
# 145459       0.7           16           39.0           2  ...         62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
df['Date']=pd.to_datetime(df['Date'],format="%Y-%m-%d",errors='coerce')

# %%
df['date_day']=df['Date'].dt.day
df['date_month']=df['Date'].dt.month
df['date_year']=df['Date'].dt.year

# %%
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-12-01         2     13.4     22.9       0.6          2.4       8.3
# 1 2008-12-02         2      7.4     25.1       0.0          3.6      10.0
# 2 2008-12-03         2     12.9     25.7       0.0          2.6       4.4
# 3 2008-12-04         2      9.2     28.0       0.0         18.4       8.9
# 4 2008-12-05         2     17.5     32.3       1.0          5.4       3.0
#
#    WindGustDir  WindGustSpeed  WindDir9am  ...  Pressure3pm  Cloud9am  \
# 0           13           44.0          13  ...       1007.1       8.0
# 1           14           44.0           6  ...       1007.8       7.0
# 2           15           46.0          13  ...       1008.7       8.0
# 3            4           24.0           9  ...       1012.8       0.0
# 4           13           41.0           1  ...       1006.0       7.0
#
#    Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  date_day  date_month  \
# ...

# %%
df=df.drop('Date',axis=1)

# %%
df.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0         2     13.4     22.9       0.6          2.4       8.3           13
# 1         2      7.4     25.1       0.0          3.6      10.0           14
# 2         2     12.9     25.7       0.0          2.6       4.4           15
# 3         2      9.2     28.0       0.0         18.4       8.9            4
# 4         2     17.5     32.3       1.0          5.4       3.0           13
#
#    WindGustSpeed  WindDir9am  WindDir3pm  ...  Pressure3pm  Cloud9am  \
# 0           44.0          13          14  ...       1007.1       8.0
# 1           44.0           6          15  ...       1007.8       7.0
# 2           46.0          13          15  ...       1008.7       8.0
# 3           24.0           9           0  ...       1012.8       0.0
# 4           41.0           1           7  ...       1006.0       7.0
#
#    Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  date_day  date_month  \
# ...

# %%
corrmat=df.corr()
plt.figure(figsize=(25,15))
sns.heatmap(corrmat,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
for feature in continuous_feature:
    data=df.copy()
    plt.figure(figsize=(5,5))
    sns.boxplot(data[feature])
    plt.title(feature)
# Out:
# C:\Users\KEERTI\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\KEERTI\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
def outliers(df,variable):
    IQR=df[variable].quantile(0.75)-df[variable].quantile(0.25)
    lower_bridge=df[variable].quantile(0.25)-(IQR*1.5)
    upper_bridge=df[variable].quantile(0.75)-(IQR*1.5)
    
    df.loc[df[variable]>=upper_bridge,variable]=upper_bridge
    df.loc[df[variable]<=lower_bridge,variable]=lower_bridge

# %%
for feature in continuous_feature:
    outliers(df,str(feature))

# %%
for feature in continuous_feature:
    data=df.copy()
    plt.figure(figsize=(5,5))
    sns.boxplot(data[feature])
    plt.title(feature)
# Out:
# C:\Users\KEERTI\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\KEERTI\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df.isnull().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# date_day         0
# date_month       0
# date_year        0
# dtype: int64

# %%
df.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0         2     3.15     12.9      -0.3          0.2       1.9           13
# 1         2     3.15     12.9      -0.3          0.2       1.9           14
# 2         2     3.15     12.9      -0.3          0.2       1.9           15
# 3         2     3.15     12.9      -0.3          0.2       1.9            4
# 4         2     3.15     12.9      -0.3          0.2       1.9           13
#
#    WindGustSpeed  WindDir9am  WindDir3pm  ...  Pressure3pm  Cloud9am  \
# 0           23.5          13          14  ...      1006.95       8.0
# 1           23.5           6          15  ...      1006.95       7.0
# 2           23.5          13          15  ...      1006.95       8.0
# 3           23.5           9           0  ...      1006.95       0.0
# 4           23.5           1           7  ...      1006.00       7.0
#
#    Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  date_day  date_month  \
# ...

# %%
x=df.iloc[:,:]
y=df.iloc[:,21]
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: RainTomorrow, dtype: uint8

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE
sm=SMOTE(random_state=0)
x_train_res,y_train_res=sm.fit_resample(x_train,y_train)
print("number of classes before fit {}".format(Counter(y_train)))
print("number of classes after fit {}".format(Counter(y_train_res)))
# Out:
# number of classes before fit Counter({0: 90953, 1: 25415})
# number of classes after fit Counter({0: 90953, 1: 90953})

# %%
from catboost import CatBoostClassifier
cat=CatBoostClassifier(iterations=2000,eval_metric='AUC')
cat.fit(x_train_res,y_train_res)
# Out:
# Learning rate set to 0.050332
# 0:	total: 60ms	remaining: 1m 59s
# 1:	total: 105ms	remaining: 1m 44s
# 2:	total: 148ms	remaining: 1m 38s
# 3:	total: 192ms	remaining: 1m 35s
# 4:	total: 235ms	remaining: 1m 33s
# 5:	total: 281ms	remaining: 1m 33s
# 6:	total: 327ms	remaining: 1m 33s
# 7:	total: 367ms	remaining: 1m 31s
# 8:	total: 415ms	remaining: 1m 31s
# 9:	total: 462ms	remaining: 1m 31s
# 10:	total: 506ms	remaining: 1m 31s
# 11:	total: 552ms	remaining: 1m 31s
# 12:	total: 598ms	remaining: 1m 31s
# 13:	total: 645ms	remaining: 1m 31s
# 14:	total: 689ms	remaining: 1m 31s
# 15:	total: 733ms	remaining: 1m 30s
# 16:	total: 778ms	remaining: 1m 30s
# 17:	total: 820ms	remaining: 1m 30s
# 18:	total: 863ms	remaining: 1m 29s
# 19:	total: 907ms	remaining: 1m 29s
# 20:	total: 950ms	remaining: 1m 29s
# 21:	total: 993ms	remaining: 1m 29s
# 22:	total: 1.03s	remaining: 1m 28s
# 23:	total: 1.08s	remaining: 1m 28s
# 24:	total: 1.12s	remaining: 1m 28s
# 25:	total: 1.16s	remaining: 1m 28s
# ...

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn import metrics

# %%
y_pred=cat.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     22726
#            1       1.00      1.00      1.00      6366
#
#     accuracy                           1.00     29092
#    macro avg       1.00      1.00      1.00     29092
# weighted avg       1.00      1.00      1.00     29092

# %%
metrics.plot_roc_curve(cat,x_test,y_test)
metrics.roc_auc_score(y_test,y_pred,average=None)
# Out:
# C:\Users\KEERTI\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# 1.0

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train_res,y_train_res)
# Out:
# RandomForestClassifier()

# %%
y_pred1=rf.predict(x_test)
print(confusion_matrix(y_test,y_pred1))
print(accuracy_score(y_test,y_pred1))
print(classification_report(y_test,y_pred1))
# Out:
# [[22726     0]
#  [    0  6366]]
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     22726
#            1       1.00      1.00      1.00      6366
#
#     accuracy                           1.00     29092
#    macro avg       1.00      1.00      1.00     29092
# weighted avg       1.00      1.00      1.00     29092

# %%
metrics.plot_roc_curve(rf,x_test,y_test)
metrics.roc_auc_score(y_test,y_pred1,average=None)
# Out:
# C:\Users\KEERTI\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# 1.0

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(x_train_res,y_train_res)
# Out:
# GaussianNB()

# %%
y_pred2=gnb.predict(x_test)
print(confusion_matrix(y_test,y_pred2))
print(accuracy_score(y_test,y_pred2))
print(classification_report(y_test,y_pred2))
# Out:
# [[22726     0]
#  [    0  6366]]
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     22726
#            1       1.00      1.00      1.00      6366
#
#     accuracy                           1.00     29092
#    macro avg       1.00      1.00      1.00     29092
# weighted avg       1.00      1.00      1.00     29092

# %%
metrics.plot_roc_curve(rf,x_test,y_test)
metrics.roc_auc_score(y_test,y_pred1,average=None)
# Out:
# C:\Users\KEERTI\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# 1.0

# %%
import pickle
filename = "final_model.pkl"
pickle.dump(cat,open(filename,'wb'))

# %%
from pandas_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\KEERTI\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_stats_py.py:4868: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
